# %% [markdown]
# ## Python is a programming language that is used for both development and analytics.
#
# ### Recently is has been the go-to language of choice for most data scientists who aim to productionalize ML models.
#
# #### For us we'll be using Python to explore data and perform certain analytical methods to be able to derive more insight from data.

# %% [markdown]
# ### In python, we're able to import different open source libraries for analysis that we can use to our advantage

# %%
import pandas as pd #load pandas (dataframe) library into the environment
import numpy as np #load numpy library into environment
from matplotlib import pyplot as plt #load plotting library into environment
import seaborn as sns#load plotting library into environment

# %%
#<------------------- Don't mind, pang arte ko lang 'to -------------------->
import warnings
warnings.filterwarnings("ignore")
pd.options.display.max_columns = 100

# Setup viz
# %matplotlib inline

TM_pal_primary = ['#ef4631', '#020202', '#3c3a3b', '#b4b4b4']

TM_pal_sequential_terr = ['#fff8ef', '#ffcc99', '#fb8a5f', '#e75031', '#c30202']
TM_pal_sequential_tund = ['#f0f0f0', '#bfbebe', '#918f90', '#656363', '#3c3a3b']

TM_pal_divergent_tc = ['#10b9ce', '#a6d9de', '#fff8ef', '#ffa68e', '#ef4631']
TM_pal_divergent_tt = ['#3c3a3b', '#989390', '#fff8ef', '#ffa68e', '#ef4631']

TM_pal_categorical_3 = ['#ef4631', '#10b9ce', '#ff9138']
TM_pal_categorical_5 = ['#ef4631', '#10b9ce', '#72dde9', '#ff9138', '#ffb478']
TM_pal_categorical_10 = ['#ef4631', '#f47f71', '#10b9ce', '#72dde9', '#2292ec',
                         '#66b4f2', '#ff9138', '#ffb478', '#3f50b0', '#7a86c8']
plt.rcParams["font.sans-serif"] = "Arial"
sns.set(style='white',
        palette=TM_pal_categorical_3,
        rc={'axes.edgecolor': TM_pal_primary[3],
            'axes.spines.top': False,
            'axes.spines.right': False,
            'font.family': ['sans-serif'],
            'font.sans-serif': ['Helvetica Neue'],
            'font.weight': 'light', # Can be medium or light
            'grid.alpha': 0.5,
            'grid.color': TM_pal_primary[3],
            'text.color': TM_pal_primary[1],
            'xtick.color': TM_pal_primary[1],
            'xtick.labelsize': 13,
            'ytick.color': TM_pal_primary[1],
            'ytick.labelsize': 13})

# %% [markdown]
# ## <span style="color:#ef4631">01</span> Define the Business Problem
# ### Say our client is a telco company, and their goal is prevent customer churn (leaving).
#
# #### They give us data on their current/previous customers, their details, previous subscriptions and whether or not they churned.

# %%
#download data from this github repository
telco = pd.read_csv('https://raw.githubusercontent.com/magtanggol03/dec130/master/datasets/telco-churn/train.csv')

#display the first three lines
telco.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
#
#   PaperlessBilling     PaymentMethod  MonthlyCharges TotalCharges Churn
# 0              Yes  Electronic check           29.85        29.85    No
# 1               No      Mailed check           56.95       1889.5    No

# %%
#Data cleaning
telco.TotalCharges = pd.to_numeric(telco.TotalCharges, errors = 'coerce')

# %% [markdown]
# ## <span style="color:#ef4631">02</span> How does the data help us address the problem?
#
# ### Given this data, what business problem can we help our customer solve?
#
# ### What are the hypotheses that we can make from?

# %%
print('There are', telco.shape[0], 'rows and', telco.shape[1], 'columns')
# Out:
# There are 500 rows and 20 columns

# %%
print(telco.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 20 columns):
# customerID          500 non-null object
# gender              500 non-null object
# SeniorCitizen       500 non-null int64
# Partner             500 non-null object
# Dependents          500 non-null object
# tenure              500 non-null int64
# PhoneService        500 non-null object
# MultipleLines       500 non-null object
# InternetService     500 non-null object
# OnlineSecurity      500 non-null object
# OnlineBackup        500 non-null object
# DeviceProtection    500 non-null object
# TechSupport         500 non-null object
# StreamingTV         500 non-null object
# StreamingMovies     500 non-null object
# Contract            500 non-null object
# PaperlessBilling    500 non-null object
# PaymentMethod       500 non-null object
# MonthlyCharges      500 non-null float64
# TotalCharges        500 non-null object
# dtypes: float64(1), int64(2), object(17)
# ...

# %% [markdown]
# ## <span style="color:#ef4631">03</span> Audit the Data
#
# ### Does the data make sense? How can I further refine my hypothesis?

# %%
telco.describe(include='all')
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         6543   6543    6543.000000    6543       6543  6543.000000
# unique        6543      2            NaN       2          2          NaN
# top     2792-LSHWX   Male            NaN      No         No          NaN
# freq             1   3315            NaN    3381       4587          NaN
# mean           NaN    NaN       0.162311     NaN        NaN    32.356564
# std            NaN    NaN       0.368764     NaN        NaN    24.582292
# min            NaN    NaN       0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN       0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    55.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
def getDist(cols):
    fig, ax = plt.subplots(2, 5, figsize = (20,10))
    idx = 0 

    for col in cols:
        temp_df = telco[col]

        if temp_df.dtype == np.int64 or temp_df.dtype == np.float64:
            temp_df.hist(ax = ax[int(idx/5), idx%5])
        else:
            pd.DataFrame(temp_df.value_counts()).plot(kind = 'bar', ax = ax[int(idx/5), idx%5])
        ax[int(idx/5), idx%5].title.set_text(col)
        idx += 1

    plt.tight_layout()

# %%
#Get the distribution of the different values of each feature/variable
getDist(telco.columns[1:11])

# %%
#Get the distribution of the different values of each feature/variable
getDist(telco.columns[12:])

# %% [markdown]
# ## <span style="color:#ef4631">04</span> Test Your Hypothesis
#
# ### Figure out what models or experiments to run to validate or invalidate your thoughts

# %%
def compWchurn(colName, ax = None):
    temp_df = telco[[colName, 'Churn']]
    
    if temp_df[colName].dtype == np.int64 or temp_df[colName].dtype == np.float64:
        temp_df[colName] = pd.cut(temp_df[colName], bins = 4)
        
    if ax == None:
        pd.crosstab(temp_df['Churn'], columns = temp_df[colName], normalize = 'index').plot(kind = 'bar', color = TM_pal_categorical_5, figsize = (10,5), stacked = True)
        plt.title('Comparison of Churning vs non-churning customers')
    else:
        pd.crosstab(temp_df['Churn'], columns = temp_df[colName], normalize = 'index').plot(kind = 'bar', color = TM_pal_categorical_5, ax = ax, stacked = True)

# %% [markdown]
# ### We can view some features relative to our dependent variable, Churn.
#
# #### For example in the chart below, we can see that there is <span style="color:#ef4631">no significant difference</span> in the distribution of gender for the population of customer who churned and didn't churn.

# %%
compWchurn('gender')

# %% [markdown]
# ### Gender probably will not be an important factor in predicting customer churn.

# %%
fig,ax = plt.subplots(2, 2, figsize = (20,10))

compWchurn('SeniorCitizen', ax[0,0])
compWchurn('Partner', ax[0,1])
compWchurn('Dependents', ax[1,0])
compWchurn('tenure', ax[1,1])
plt.tight_layout()

# %% [markdown]
# ## HOMEWORK
#
# Download the testing set of this data at
# https://raw.githubusercontent.com/magtanggol03/dec130/master/datasets/telco-churn/test.csv

# %%
#download data from this github repository
telco = pd.read_csv('https://raw.githubusercontent.com/magtanggol03/dec130/master/datasets/telco-churn/test.csv')

#display the first three lines
telco.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  8050-XGRVL  Female              0     Yes        Yes      62          Yes
# 1  6661-HBGWL  Female              1      No         No      42          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL            Yes           No              Yes
# 1           Yes     Fiber optic             No          Yes              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No        One year               No
# 1          No         Yes             Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges
# 0    Credit card (automatic)           54.75      3425.35
# 1  Bank transfer (automatic)          104.75      4323.45

# %% [markdown]
# This contains 500 customers with all the same data, except the Churning data.
# By next week, submit the dataset with your predictions on whether or not each customer will Churn or not.
# No need to use Python (feel free to use excel or your own personal judgement).
#
# Then submit your predictions on an excel file with ONLY TWO COLUMNS, customerID and Churn (your prediction) and a ONE PAGE PAPER MAX on the thought behind your predictions.
#
# Submit here: https://drive.google.com/drive/folders/1opyNiGcaW7r1-KyuK286kWqdnB7Kul4q
